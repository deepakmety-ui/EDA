# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes.csv")

# %%
df['']
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=df['SkinThickness']
plt.plot(a)

# %%
b=df['Glucose']
plt.plot(b)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
x=[2,3,5,6,10]
plt.plot(x)

# %%
a=df['Pregnancies']

# %%
b=df['Pregnancies']
c=df['Glucose']
plt.scatter(b,c)

# %%
b=df['Age']
c=df['Glucose']
plt.bar(b,c)
# Out:
# <BarContainer object of 768 artists>

# %%
plt.hist(b)
# Out:
# (array([300., 157.,  92.,  86.,  52.,  34.,  26.,  16.,   4.,   1.]),
#  array([21., 27., 33., 39., 45., 51., 57., 63., 69., 75., 81.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(c)
# Out:
# (array([  5.,   0.,   4.,  32., 156., 211., 163.,  95.,  56.,  46.]),
#  array([  0. ,  19.9,  39.8,  59.7,  79.6,  99.5, 119.4, 139.3, 159.2,
#         179.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b)
# Out:
# (array([231., 107., 165., 175.,  78.,   9.,   2.,   0.,   0.,   1.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a14160c9be0>,
#   <matplotlib.patches.Wedge at 0x7a14160b17c0>,
#   <matplotlib.patches.Wedge at 0x7a14160ca3c0>,
#   <matplotlib.patches.Wedge at 0x7a14160ca750>,
#   <matplotlib.patches.Wedge at 0x7a14175631a0>],
#  [Text(1.0680359967948738, 0.2632472403471312, ''),
#   Text(0.7294348858100299, 0.823361856879045, ''),
#   Text(-0.2632472552025161, 1.0680359931333503, ''),
#   Text(-1.0999999999999959, -9.616505800409723e-08, ''),
#   Text(0.39006553985843684, -1.028517804714603, '')])

# %%
sns.lineplot(b)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %%
sns.barplot(b)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.distplot(b)
# Out:
# /tmp/ipykernel_11957/1062453464.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(b)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(b)

# %%
sns.barplot(a)
# Out:
# <Axes: ylabel='Pregnancies'>
