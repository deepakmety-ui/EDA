# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/iron_alloys.csv")

# %%
df.shape
# Out:
# (1392, 110)

# %%
df.describe()
# Out:
#        Elastic (Young's, Tensile) Modulus (psi)  Elongation at Break (%)  \
# count                               1392.000000              1176.000000
# mean                                 192.830460                21.824660
# std                                    6.711043                11.494569
# min                                  140.000000                 1.000000
# 25%                                  190.000000                12.000000
# 50%                                  190.000000                20.000000
# 75%                                  200.000000                28.000000
# max                                  210.000000                60.000000
#
#        Shear Modulus (psi)  Tensile Strength: Ultimate (UTS) (psi)  \
# count          1391.000000                             1389.000000
# mean             74.700935                              651.187905
# std               3.008332                              250.899448
# ...

# %%
df.head()
# Out:
#                                      iron_alloy_name  \
# 0       SAE-ASTM Grade G2500 (F10005) Grey Cast Iron
# 1      SAE-ASTM Grade G2500a (F10009) Grey Cast Iron
# 2       SAE-ASTM Grade G3000 (F10006) Grey Cast Iron
# 3      SAE-ASTM Grade G4000d (F10012) Grey Cast Iron
# 4  ASTM A897 Grade 1 (ASTM 130-90-09 or 900-650-0...
#
#    Elastic (Young's, Tensile) Modulus (psi)  Elongation at Break (%)  \
# 0                                       180                     14.0
# 1                                       180                     14.0
# 2                                       180                      9.6
# 3                                       180                      9.6
# 4                                       180                     10.0
#
#    Shear Modulus (psi)  Tensile Strength: Ultimate (UTS) (psi)  \
# 0                 69.0                                   190.0
# 1                 69.0                                   190.0
# ...

# %%
df.isnull().sum()
# Out:
# iron_alloy_name                                0
# Elastic (Young's, Tensile) Modulus (psi)       0
# Elongation at Break (%)                      216
# Shear Modulus (psi)                            1
# Tensile Strength: Ultimate (UTS) (psi)         3
#                                             ...
# Lanthanum (La)La max                        1389
# Zinc (Zn)Zn min                             1391
# Zinc (Zn)Zn max                             1391
# Lead (Pb)Pb min                             1389
# Lead (Pb)Pb max                             1389
# Length: 110, dtype: int64
